# %%
import pandas as pd
import numpy as np
import pickle

# %%
L_cap = pd.read_csv("./data/stock_spy.csv")
L_cap = L_cap.loc[L_cap['date']>'2016-01-01']
L_cap.head()
# Out:
#             date    open    high     low   close       volume    change
# 4068  2016-01-04  200.49  201.03  198.59  201.02  222353500.0  0.002644
# 4069  2016-01-05  201.40  201.90  200.05  201.36  110845800.0 -0.000199
# 4070  2016-01-06  198.34  200.06  197.60  198.82  152112600.0  0.002420
# 4071  2016-01-07  195.33  197.44  193.59  194.05  213436100.0 -0.006553
# 4072  2016-01-08  195.19  195.85  191.58  191.92  209817200.0 -0.016753

# %%
M_cap = pd.read_csv("./data/stock_mdy.csv")
M_cap = M_cap.loc[M_cap['date']>'2016-01-01']
M_cap.head()
# Out:
#             date    open    high     low   close     volume    change
# 4068  2016-01-04  249.92  250.82  248.24  250.82  5094674.0  0.003601
# 4069  2016-01-05  251.23  251.79  249.63  250.90  3856769.0 -0.001314
# 4070  2016-01-06  247.62  249.18  246.04  247.36  5394041.0 -0.001050
# 4071  2016-01-07  243.32  244.97  240.85  241.04  6412601.0 -0.009370
# 4072  2016-01-08  242.00  242.83  237.61  237.82  4343081.0 -0.017273

# %%
S_cap = pd.read_csv("./data/stock_ijr.csv")
S_cap = S_cap.loc[S_cap['date']>'2016-01-01']
S_cap.head()
# Out:
#             date    open      high     low   close     volume    change
# 3924  2016-01-04  108.26  108.3000  106.64  107.54  1535455.0 -0.006651
# 3925  2016-01-05  107.85  108.0900  107.16  107.87   763638.0  0.000185
# 3926  2016-01-06  106.39  107.3600  106.05  106.64   725463.0  0.002350
# 3927  2016-01-07  104.63  105.5999  103.74  103.90  1782852.0 -0.006977
# 3928  2016-01-08  104.28  104.7150  102.04  102.17  1440398.0 -0.020234

# %%
wsb_econ = pd.read_csv("./data/wsb_daydf_count.csv")
wsb_econ.head()
# Out:
#          Date  Count
# 0  2016-01-01      7
# 1  2016-01-03     28
# 2  2016-01-04      8
# 3  2016-01-05      5
# 4  2016-01-06     17

# %%
wsb_favd = pd.read_csv("./data/wsb_favd_count.csv")
wsb_favd.head()
# Out:
#           day  favorites
# 0  2016-01-01         25
# 1  2016-01-02         37
# 2  2016-01-03        159
# 3  2016-01-04        224
# 4  2016-01-05        156

# %%
wsb_sentbyday = pd.read_csv("./data/wsb_sentbydaydf_count.csv")
wsb_sentbyday.head()
# Out:
#          Date  Sent_Count
# 0  2016-01-01          17
# 1  2016-01-02           0
# 2  2016-01-03          30
# 3  2016-01-04          -2
# 4  2016-01-05          -8

# %%
wsb_sentbydaypos = pd.read_csv("./data/wsb_sentbydayposdf_count.csv")
wsb_sentbydaypos.head()
# Out:
#          Date  Pos_Count
# 0  2016-01-01         23
# 1  2016-01-02          2
# 2  2016-01-03         88
# 3  2016-01-04         28
# 4  2016-01-05         19

# %%
wsb_sentbydayneg = pd.read_csv("./data/wsb_sentbydaynegdf_count.csv")
wsb_sentbydayneg.head()
# Out:
#          Date  Neg_Count
# 0  2016-01-01          6
# 1  2016-01-02          2
# 2  2016-01-03         58
# 3  2016-01-04         30
# 4  2016-01-05         27

# %%
wsb_mkt = L_cap.merge(wsb_sentbydayneg, how='inner', left_on="date" ,right_on="Date")
wsb_mkt = wsb_mkt.merge(wsb_sentbydaypos, how='inner' ,on="Date")
wsb_mkt =  wsb_mkt.merge(wsb_sentbyday, how='inner' ,on="Date")
wsb_mkt =  wsb_mkt.merge(wsb_favd, how='inner' , left_on="date" ,right_on="day")
wsb_mkt =  wsb_mkt.merge(wsb_econ, how='inner' ,on="Date")
wsb_mkt['pos_neg'] = np.where (wsb_mkt['change'] > 0,1,0)
wsb_mkt['pos'] = np.where (wsb_mkt['change'] > 0.002,1,0)
wsb_mkt['neg'] = np.where (wsb_mkt['change'] < -0.002,1,0)
wsb_mkt['flat'] = np.where ((wsb_mkt['change'] <= 0.002) & (wsb_mkt['change'] >= -0.002) ,1,0)

wsb_mkt
# Out:
#             date    open    high       low   close       volume    change  \
# 0     2016-01-04  200.49  201.03  198.5900  201.02  222353500.0  0.002644
# 1     2016-01-05  201.40  201.90  200.0500  201.36  110845800.0 -0.000199
# 2     2016-01-06  198.34  200.06  197.6000  198.82  152112600.0  0.002420
# 3     2016-01-07  195.33  197.44  193.5900  194.05  213436100.0 -0.006553
# 4     2016-01-08  195.19  195.85  191.5800  191.92  209817200.0 -0.016753
# ...          ...     ...     ...       ...     ...          ...       ...
# 1317  2021-04-26  417.44  418.22  416.8111  417.61   52182392.0  0.000407
# 1318  2021-04-27  417.93  418.14  416.3000  417.52   51303056.0 -0.000981
# 1319  2021-04-28  417.81  419.01  416.9000  417.40   51238854.0 -0.000981
# 1320  2021-04-29  420.32  420.72  416.4400  420.06   78544329.0 -0.000619
# 1321  2021-04-30  417.63  418.54  416.3400  417.30   85527030.0 -0.000790
#
#             Date  Neg_Count  Pos_Count  Sent_Count         day  favorites  \
# 0     2016-01-04         30         28          -2  2016-01-04        224
# 1     2016-01-05         27         19          -8  2016-01-05        156
# 2     2016-01-06         62         39         -23  2016-01-06        664
# 3     2016-01-07         84         79          -5  2016-01-07        605
# 4     2016-01-08         76         75          -1  2016-01-08        206
# ...          ...        ...        ...         ...         ...        ...
# 1317  2021-04-26        406        755         349  2021-04-26        494
# 1318  2021-04-27        617       1137         520  2021-04-27        558
# 1319  2021-04-28        600       1104         504  2021-04-28        452
# 1320  2021-04-29        462        805         343  2021-04-29        455
# 1321  2021-04-30        894       1187         293  2021-04-30        424
#
#       Count  pos_neg  pos  neg  flat
# 0         8        1    1    0     0
# 1         5        0    0    0     1
# 2        17        1    1    0     0
# 3        18        0    0    1     0
# 4        20        0    0    1     0
# ...     ...      ...  ...  ...   ...
# 1317    145        1    0    0     1
# 1318    214        0    0    0     1
# 1319    184        0    0    0     1
# 1320    153        0    0    0     1
# 1321    197        0    0    0     1
#
# [1322 rows x 18 columns]

# %%
wsb_mkt['negcount1day'] = wsb_mkt['Neg_Count'].shift(1)
wsb_mkt['poscount1day'] = wsb_mkt['Pos_Count'].shift(1)
#wsb_mkt['sentcount1day'] = wsb_mkt['Sent_Count'].shift(1)
wsb_mkt['favcount1day'] = wsb_mkt['favorites'].shift(1)
wsb_mkt['econcount1day'] = wsb_mkt['Count'].shift(1)
wsb_mkt['change1day'] = wsb_mkt['change'].shift(1)
wsb_mkt['negcount2day'] = wsb_mkt['Neg_Count'].shift(2)
wsb_mkt['poscount2day'] = wsb_mkt['Pos_Count'].shift(2)
#wsb_mkt['sentcount2day'] = wsb_mkt['Sent_Count'].shift(2)
wsb_mkt['favcount2day'] = wsb_mkt['favorites'].shift(2)
wsb_mkt['econcount2day'] = wsb_mkt['Count'].shift(2)
wsb_mkt['change2day'] = wsb_mkt['change'].shift(2)
wsb_mkt['negcount3day'] = wsb_mkt['Neg_Count'].shift(3)
wsb_mkt['poscount3day'] = wsb_mkt['Pos_Count'].shift(3)
#wsb_mkt['sentcount3day'] = wsb_mkt['Sent_Count'].shift(3)
wsb_mkt['favcount3day'] = wsb_mkt['favorites'].shift(3)
wsb_mkt['econcount3day'] = wsb_mkt['Count'].shift(3)
wsb_mkt['change3day'] = wsb_mkt['change'].shift(3)
wsb_mkt['negcount4day'] = wsb_mkt['Neg_Count'].shift(4)
wsb_mkt['poscount4day'] = wsb_mkt['Pos_Count'].shift(4)
#wsb_mkt['sentcount4day'] = wsb_mkt['Sent_Count'].shift(4)
wsb_mkt['favcount4day'] = wsb_mkt['favorites'].shift(4)
wsb_mkt['econcount4day'] = wsb_mkt['Count'].shift(4)
wsb_mkt['change4day'] = wsb_mkt['change'].shift(4)
wsb_mkt['negcount5day'] = wsb_mkt['Neg_Count'].shift(5)
wsb_mkt['poscount5day'] = wsb_mkt['Pos_Count'].shift(5)
#wsb_mkt['sentcount5day'] = wsb_mkt['Sent_Count'].shift(5)
wsb_mkt['favcount5day'] = wsb_mkt['favorites'].shift(5)
wsb_mkt['econcount5day'] = wsb_mkt['Count'].shift(5)
wsb_mkt['change5day'] = wsb_mkt['change'].shift(5)
wsb_mkt['negcount6day'] = wsb_mkt['Neg_Count'].shift(6)
wsb_mkt['poscount6day'] = wsb_mkt['Pos_Count'].shift(6)
#sb_mkt['sentcount6day'] = wsb_mkt['Sent_Count'].shift(6)
wsb_mkt['favcount6day'] = wsb_mkt['favorites'].shift(6)
wsb_mkt['econcount6day'] = wsb_mkt['Count'].shift(6)
wsb_mkt['change6day'] = wsb_mkt['change'].shift(6)
wsb_mkt['negcount7day'] = wsb_mkt['Neg_Count'].shift(7)
wsb_mkt['poscount7day'] = wsb_mkt['Pos_Count'].shift(7)
#wsb_mkt['sentcount7day'] = wsb_mkt['Sent_Count'].shift(7)
wsb_mkt['favcount7day'] = wsb_mkt['favorites'].shift(7)
wsb_mkt['econcount7day'] = wsb_mkt['Count'].shift(7)
wsb_mkt['change7day'] = wsb_mkt['change'].shift(7)
wsb_mkt['negcount8day'] = wsb_mkt['Neg_Count'].shift(8)
wsb_mkt['poscount8day'] = wsb_mkt['Pos_Count'].shift(8)
#wsb_mkt['sentcount8day'] = wsb_mkt['Sent_Count'].shift(8)
wsb_mkt['favcount8day'] = wsb_mkt['favorites'].shift(8)
wsb_mkt['econcount8day'] = wsb_mkt['Count'].shift(8)
wsb_mkt['change8day'] = wsb_mkt['change'].shift(8)
wsb_mkt['negcount9day'] = wsb_mkt['Neg_Count'].shift(9)
wsb_mkt['poscount9day'] = wsb_mkt['Pos_Count'].shift(9)
#wsb_mkt['sentcount9day'] = wsb_mkt['Sent_Count'].shift(9)
wsb_mkt['favcount9day'] = wsb_mkt['favorites'].shift(9)
wsb_mkt['econcount9day'] = wsb_mkt['Count'].shift(9)
wsb_mkt['change9day'] = wsb_mkt['change'].shift(9)
wsb_mkt['negcount10day'] = wsb_mkt['Neg_Count'].shift(10)
wsb_mkt['poscount10day'] = wsb_mkt['Pos_Count'].shift(10)
#wsb_mkt['sentcount10day'] = wsb_mkt['Sent_Count'].shift(10)
wsb_mkt['favcount10day'] = wsb_mkt['favorites'].shift(10)
wsb_mkt['econcount10day'] = wsb_mkt['Count'].shift(10)
wsb_mkt['change10day'] = wsb_mkt['change'].shift(10)
wsb_mkt['negcount11day'] = wsb_mkt['Neg_Count'].shift(11)
wsb_mkt['poscount11day'] = wsb_mkt['Pos_Count'].shift(11)
#wsb_mkt['sentcount11day'] = wsb_mkt['Sent_Count'].shift(11)
wsb_mkt['favcount11day'] = wsb_mkt['favorites'].shift(11)
wsb_mkt['econcount11day'] = wsb_mkt['Count'].shift(11)
wsb_mkt['change11day'] = wsb_mkt['change'].shift(11)
wsb_mkt['negcount12day'] = wsb_mkt['Neg_Count'].shift(12)
wsb_mkt['poscount12day'] = wsb_mkt['Pos_Count'].shift(12)
#wsb_mkt['sentcount12day'] = wsb_mkt['Sent_Count'].shift(12)
wsb_mkt['favcount12day'] = wsb_mkt['favorites'].shift(12)
wsb_mkt['econcount12day'] = wsb_mkt['Count'].shift(12)
wsb_mkt['change12day'] = wsb_mkt['change'].shift(12)
wsb_mkt['negcount13day'] = wsb_mkt['Neg_Count'].shift(13)
wsb_mkt['poscount13day'] = wsb_mkt['Pos_Count'].shift(13)
#wsb_mkt['sentcount13day'] = wsb_mkt['Sent_Count'].shift(13)
wsb_mkt['favcount13day'] = wsb_mkt['favorites'].shift(13)
wsb_mkt['econcount13day'] = wsb_mkt['Count'].shift(13)
wsb_mkt['change13day'] = wsb_mkt['change'].shift(13)
wsb_mkt['negcount14day'] = wsb_mkt['Neg_Count'].shift(14)
wsb_mkt['poscount14day'] = wsb_mkt['Pos_Count'].shift(14)
# wsb_mkt['sentcount14day'] = wsb_mkt['Sent_Count'].shift(14)
wsb_mkt['favcount14day'] = wsb_mkt['favorites'].shift(14)
wsb_mkt['econcount14day'] = wsb_mkt['Count'].shift(14)
wsb_mkt['change14day'] = wsb_mkt['change'].shift(14)
wsb_mkt['negcount15day'] = wsb_mkt['Neg_Count'].shift(15)
wsb_mkt['poscount15day'] = wsb_mkt['Pos_Count'].shift(15)
# wsb_mkt['sentcount15day'] = wsb_mkt['Sent_Count'].shift(15)
wsb_mkt['favcount15day'] = wsb_mkt['favorites'].shift(15)
wsb_mkt['econcount15day'] = wsb_mkt['Count'].shift(15)
wsb_mkt['change15day'] = wsb_mkt['change'].shift(15)
wsb_mkt
# Out:
#             date    open    high       low   close       volume    change  \
# 0     2016-01-04  200.49  201.03  198.5900  201.02  222353500.0  0.002644
# 1     2016-01-05  201.40  201.90  200.0500  201.36  110845800.0 -0.000199
# 2     2016-01-06  198.34  200.06  197.6000  198.82  152112600.0  0.002420
# 3     2016-01-07  195.33  197.44  193.5900  194.05  213436100.0 -0.006553
# 4     2016-01-08  195.19  195.85  191.5800  191.92  209817200.0 -0.016753
# ...          ...     ...     ...       ...     ...          ...       ...
# 1317  2021-04-26  417.44  418.22  416.8111  417.61   52182392.0  0.000407
# 1318  2021-04-27  417.93  418.14  416.3000  417.52   51303056.0 -0.000981
# 1319  2021-04-28  417.81  419.01  416.9000  417.40   51238854.0 -0.000981
# 1320  2021-04-29  420.32  420.72  416.4400  420.06   78544329.0 -0.000619
# 1321  2021-04-30  417.63  418.54  416.3400  417.30   85527030.0 -0.000790
#
#             Date  Neg_Count  Pos_Count  ...  negcount14day poscount14day  \
# 0     2016-01-04         30         28  ...            NaN           NaN
# 1     2016-01-05         27         19  ...            NaN           NaN
# 2     2016-01-06         62         39  ...            NaN           NaN
# 3     2016-01-07         84         79  ...            NaN           NaN
# 4     2016-01-08         76         75  ...            NaN           NaN
# ...          ...        ...        ...  ...            ...           ...
# 1317  2021-04-26        406        755  ...         1115.0        1520.0
# 1318  2021-04-27        617       1137  ...          454.0         694.0
# 1319  2021-04-28        600       1104  ...          495.0         711.0
# 1320  2021-04-29        462        805  ...          879.0        1380.0
# 1321  2021-04-30        894       1187  ...          825.0        1074.0
#
#       favcount14day  econcount14day  change14day  negcount15day  \
# 0               NaN             NaN          NaN            NaN
# 1               NaN             NaN          NaN            NaN
# 2               NaN             NaN          NaN            NaN
# 3               NaN             NaN          NaN            NaN
# 4               NaN             NaN          NaN            NaN
# ...             ...             ...          ...            ...
# 1317          602.0           328.0     0.005547          942.0
# 1318          467.0           123.0     0.007188         1115.0
# 1319          373.0           151.0     0.000887          454.0
# 1320          452.0           197.0     0.001601          495.0
# 1321          492.0           206.0     0.001446          879.0
#
#       poscount15day  favcount15day  econcount15day  change15day
# 0               NaN            NaN             NaN          NaN
# 1               NaN            NaN             NaN          NaN
# 2               NaN            NaN             NaN          NaN
# 3               NaN            NaN             NaN          NaN
# 4               NaN            NaN             NaN          NaN
# ...             ...            ...             ...          ...
# 1317         1234.0          559.0           222.0     0.002504
# 1318         1520.0          602.0           328.0     0.005547
# 1319          694.0          467.0           123.0     0.007188
# 1320          711.0          373.0           151.0     0.000887
# 1321         1380.0          452.0           197.0     0.001601
#
# [1322 rows x 93 columns]

# %%
wsb_mkt.to_csv('./Data/wsb_lmkt.csv', index=False)

# %%
for x in wsb_mkt.columns:
    print(x)
# Out:
# date
# open
# high
# low
# close
# volume
# change
# Date
# Neg_Count
# Pos_Count
# Sent_Count
# day
# favorites
# Count
# pos_neg
# pos
# neg
# flat
# negcount1day
# poscount1day
# favcount1day
# econcount1day
# change1day
# negcount2day
# poscount2day
# favcount2day
# econcount2day
# change2day
# negcount3day
# poscount3day
# favcount3day
# econcount3day
# change3day
# negcount4day
# poscount4day
# favcount4day
# econcount4day
# change4day
# negcount5day
# poscount5day
# favcount5day
# econcount5day
# change5day
# negcount6day
# poscount6day
# favcount6day
# econcount6day
# change6day
# negcount7day
# poscount7day
# favcount7day
# econcount7day
# change7day
# negcount8day
# poscount8day
# favcount8day
# econcount8day
# change8day
# negcount9day
# poscount9day
# favcount9day
# econcount9day
# change9day
# negcount10day
# poscount10day
# favcount10day
# econcount10day
# change10day
# negcount11day
# poscount11day
# favcount11day
# econcount11day
# change11day
# negcount12day
# poscount12day
# favcount12day
# econcount12day
# change12day
# negcount13day
# poscount13day
# favcount13day
# econcount13day
# change13day
# negcount14day
# poscount14day
# favcount14day
# econcount14day
# change14day
# negcount15day
# poscount15day
# favcount15day
# econcount15day
# change15day

# %%
wsb_mkt.dropna(inplace=True)
wsb_lmkt_x = wsb_mkt.iloc[:, np.r_[7:10,12:14,18:53]]
wsb_lmkt_x.set_index("Date", inplace=True)
wsb_lmkt_y1 = wsb_mkt['pos_neg']
wsb_lmkt_y2 = wsb_mkt[['pos','neg','flat']]
wsb_lmkt_x
wsb_lmkt_x.to_csv('./Data/wsb_lmkt_x.csv', index=True)
wsb_lmkt_y1.to_csv('./Data/wsb_lmkt_y1.csv', index=False)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
X_train, X_test,y_train,y_test = train_test_split(wsb_lmkt_x, wsb_lmkt_y1,  random_state=24)
regr = LogisticRegression()
regr.fit(X_train,y_train)
regr.score(X_test, y_test)
regr.predict_proba(X_test)
# Out:
# C:\Users\areer\Anaconda3\envs\pandas\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# array([[4.70995250e-01, 5.29004750e-01],
#        [4.78203684e-01, 5.21796316e-01],
#        [5.40585659e-01, 4.59414341e-01],
#        [5.30705108e-01, 4.69294892e-01],
#        [5.55064612e-01, 4.44935388e-01],
#        [4.98108430e-01, 5.01891570e-01],
#        [4.78920837e-01, 5.21079163e-01],
#        [5.79190550e-01, 4.20809450e-01],
#        [5.12592321e-01, 4.87407679e-01],
#        [5.27881589e-01, 4.72118411e-01],
#        [5.21508812e-01, 4.78491188e-01],
#        [4.13638188e-01, 5.86361812e-01],
#        [5.01756023e-01, 4.98243977e-01],
#        [4.31396637e-01, 5.68603363e-01],
#        [1.61788030e-01, 8.38211970e-01],
#        [4.90863374e-01, 5.09136626e-01],
#        [4.80225267e-01, 5.19774733e-01],
#        [4.20100140e-01, 5.79899860e-01],
#        [4.57357687e-01, 5.42642313e-01],
#        [4.03704105e-01, 5.96295895e-01],
#        [3.75609617e-01, 6.24390383e-01],
#        [4.83608598e-01, 5.16391402e-01],
#        [3.56860735e-01, 6.43139265e-01],
#        [5.86114848e-01, 4.13885152e-01],
#        [4.56865847e-01, 5.43134153e-01],
#        [4.76327873e-01, 5.23672127e-01],
#        [3.81765230e-01, 6.18234770e-01],
#        [4.17693073e-01, 5.82306927e-01],
#        [5.06094350e-01, 4.93905650e-01],
#        [5.05318723e-01, 4.94681277e-01],
#        [4.89312287e-01, 5.10687713e-01],
#        [4.67938476e-01, 5.32061524e-01],
#        [5.19438934e-01, 4.80561066e-01],
#        [4.81210479e-01, 5.18789521e-01],
#        [3.50656785e-01, 6.49343215e-01],
#        [4.04552468e-01, 5.95447532e-01],
#        [5.15229910e-01, 4.84770090e-01],
#        [5.47767233e-01, 4.52232767e-01],
#        [2.02696280e-01, 7.97303720e-01],
#        [5.17827274e-01, 4.82172726e-01],
#        [4.88346017e-01, 5.11653983e-01],
#        [4.54919034e-01, 5.45080966e-01],
#        [4.98002867e-01, 5.01997133e-01],
#        [5.11525542e-01, 4.88474458e-01],
#        [5.38870545e-01, 4.61129455e-01],
#        [4.25565269e-01, 5.74434731e-01],
#        [4.66558954e-01, 5.33441046e-01],
#        [1.64126413e-01, 8.35873587e-01],
#        [4.78986029e-01, 5.21013971e-01],
#        [4.89626127e-01, 5.10373873e-01],
#        [5.26685191e-01, 4.73314809e-01],
#        [5.14291146e-01, 4.85708854e-01],
#        [4.32361866e-01, 5.67638134e-01],
#        [7.38665403e-01, 2.61334597e-01],
#        [5.00598336e-01, 4.99401664e-01],
#        [5.33599707e-01, 4.66400293e-01],
#        [4.90455998e-01, 5.09544002e-01],
#        [3.78411568e-01, 6.21588432e-01],
#        [4.10445119e-01, 5.89554881e-01],
#        [4.84285902e-01, 5.15714098e-01],
#        [5.08538215e-01, 4.91461785e-01],
#        [4.92823210e-01, 5.07176790e-01],
#        [4.97751053e-01, 5.02248947e-01],
#        [4.52824688e-01, 5.47175312e-01],
#        [4.63245780e-01, 5.36754220e-01],
#        [4.53483195e-01, 5.46516805e-01],
#        [4.81781407e-01, 5.18218593e-01],
#        [5.08058687e-01, 4.91941313e-01],
#        [1.89838617e-06, 9.99998102e-01]])

# %%
filename = 'wsb_lgcap_model.sav'
pickle.dump(regr, open(filename, 'wb'))
 
# some time later...
 
# load the model from disk
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.score(X_test, y_test)
print(result)
# Out:
# 0.5504587155963303

# %%
LC_change = wsb_mkt.loc[:, ["change"]].values
LC_change
wsb_lmkt_X = wsb_mkt.loc[:,["Neg_Count", "Pos_Count", "favorites", "Count"]].values
wsb_lmkt_X
# Out:
# array([[  72,   72,  500,   16],
#        [  36,   42,  337,   18],
#        [  33,   42,  608,   14],
#        ...,
#        [ 600, 1104,  452,  184],
#        [ 462,  805,  455,  153],
#        [ 894, 1187,  424,  197]], dtype=int64)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
X_train, X_test,y_train,y_test = train_test_split(wsb_lmkt_X, LC_change, test_size=0.33 , random_state=24)
regr = RandomForestRegressor()
regr.fit(X_train,y_train)
regr.score(X_test, y_test)
# Out:
# C:\Users\areer\Anaconda3\envs\pandas\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\areer\Anaconda3\envs\pandas\lib\site-packages\ipykernel_launcher.py:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """
# -0.23763178928590456

# %%
from sklearn.linear_model import Ridge
ridge=Ridge()
ridge.fit(X_train,y_train)
ridge.score(X_test, y_test)
# Out:
# -0.0010802763171462448

# %%
LC_change = wsb_mkt.loc[:, ["change"]].values
LC_change
wsb_lmkt_X1 = wsb_mkt.loc[:,["Sent_Count", "favorites", "Count"]].values
wsb_lmkt_X1
# Out:
# array([[  0, 500,  16],
#        [  6, 337,  18],
#        [  9, 608,  14],
#        ...,
#        [504, 452, 184],
#        [343, 455, 153],
#        [293, 424, 197]], dtype=int64)

# %%
X_train, X_test,y_train,y_test = train_test_split(wsb_lmkt_X1, LC_change, test_size=0.33 , random_state=24)
regr = RandomForestRegressor()
regr.fit(X_train,y_train)
regr.score(X_test, y_test)
# Out:
# C:\Users\areer\Anaconda3\envs\pandas\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\areer\Anaconda3\envs\pandas\lib\site-packages\ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# -0.1609143630438492

# %%
ridge.fit(X_train,y_train)
ridge.score(X_test, y_test)
# Out:
# 0.00045417373466483113

# %%
from sklearn.metrics import r2_score
r2_score(y_test, regr.predict(X_test))
#r2_score(y_train, regr.predict(X_train))
# Out:
# -0.1609143630438492

# %%
y_change = ridge.predict(wsb_lmkt_X1)

# %%
r2_score(wsb_lmkt['change'], y_change)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-bb9c35436113> in <module>
# ----> 1 r2_score(wsb_lmkt['change'], y_change)
#
# NameError: name 'wsb_lmkt' is not defined

# %%
y_test = ridge.predict(X_test)
r2_score(y_train, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-9b0825669f3d> in <module>
#       1 y_test = ridge.predict(X_test)
# ----> 2 r2_score(y_train, y_test)
#
# ~\Anaconda3\envs\pandas\lib\site-packages\sklearn\metrics\regression.py in r2_score(y_true, y_pred, sample_weight, multioutput)
#     536     """
#     537     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 538         y_true, y_pred, multioutput)
#     539     check_consistent_length(y_true, y_pred, sample_weight)
#     540
#
# ~\Anaconda3\envs\pandas\lib\site-packages\sklearn\metrics\regression.py in _check_reg_targets(y_true, y_pred, multioutput)
#      75
#      76     """
# ---> 77     check_consistent_length(y_true, y_pred)
#      78     y_true = check_array(y_true, ensure_2d=False)
#      79     y_pred = check_array(y_pred, ensure_2d=False)
#
# ~\Anaconda3\envs\pandas\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     203     if len(uniques) > 1:
#     204         raise ValueError("Found input variables with inconsistent numbers of"
# --> 205                          " samples: %r" % [int(l) for l in lengths])
#     206
#     207
#
# ValueError: Found input variables with inconsistent numbers of samples: [875, 432]

# %%
wsb_mktm = M_cap.merge(wsb_sentbydayneg, how='inner', left_on="date" ,right_on="Date")
wsb_mktm = wsb_mktm.merge(wsb_sentbydaypos, how='inner' ,on="Date")
wsb_mktm =  wsb_mktm.merge(wsb_sentbyday, how='inner' ,on="Date")
wsb_mktm =  wsb_mktm.merge(wsb_favd, how='inner' , left_on="date" ,right_on="day")
wsb_mktm =  wsb_mktm.merge(wsb_econ, how='inner' ,on="Date")
wsb_mktm
# Out:
#             date    open    high     low   close     volume    change  \
# 0     2016-01-04  249.92  250.82  248.24  250.82  5094674.0  0.003601
# 1     2016-01-05  251.23  251.79  249.63  250.90  3856769.0 -0.001314
# 2     2016-01-06  247.62  249.18  246.04  247.36  5394041.0 -0.001050
# 3     2016-01-07  243.32  244.97  240.85  241.04  6412601.0 -0.009370
# 4     2016-01-08  242.00  242.83  237.61  237.82  4343081.0 -0.017273
# ...          ...     ...     ...     ...     ...        ...       ...
# 1317  2021-04-26  502.54  504.26  501.64  502.67   998318.0  0.000259
# 1318  2021-04-27  503.44  504.60  500.85  503.35   525200.0 -0.000179
# 1319  2021-04-28  502.92  504.92  502.13  503.43   782362.0  0.001014
# 1320  2021-04-29  506.89  507.63  499.78  503.43   941346.0 -0.006826
# 1321  2021-04-30  500.01  501.26  495.75  496.58  1382917.0 -0.006860
#
#             Date  Neg_Count  Pos_Count  Sent_Count         day  favorites  \
# 0     2016-01-04         30         28          -2  2016-01-04        224
# 1     2016-01-05         27         19          -8  2016-01-05        156
# 2     2016-01-06         62         39         -23  2016-01-06        664
# 3     2016-01-07         84         79          -5  2016-01-07        605
# 4     2016-01-08         76         75          -1  2016-01-08        206
# ...          ...        ...        ...         ...         ...        ...
# 1317  2021-04-26        406        755         349  2021-04-26        494
# 1318  2021-04-27        617       1137         520  2021-04-27        558
# 1319  2021-04-28        600       1104         504  2021-04-28        452
# 1320  2021-04-29        462        805         343  2021-04-29        455
# 1321  2021-04-30        894       1187         293  2021-04-30        424
#
#       Count
# 0         8
# 1         5
# 2        17
# 3        18
# 4        20
# ...     ...
# 1317    145
# 1318    214
# 1319    184
# 1320    153
# 1321    197
#
# [1322 rows x 14 columns]

# %%
wsb_mmkt = wsb_mktm.loc[:, ["date", "change", "Neg_Count", "Pos_Count", "Sent_Count", "favorites", "Count"]]
wsb_mmkt
# Out:
#             date    change  Neg_Count  Pos_Count  Sent_Count  favorites  Count
# 0     2016-01-04  0.003601         30         28          -2        224      8
# 1     2016-01-05 -0.001314         27         19          -8        156      5
# 2     2016-01-06 -0.001050         62         39         -23        664     17
# 3     2016-01-07 -0.009370         84         79          -5        605     18
# 4     2016-01-08 -0.017273         76         75          -1        206     20
# ...          ...       ...        ...        ...         ...        ...    ...
# 1317  2021-04-26  0.000259        406        755         349        494    145
# 1318  2021-04-27 -0.000179        617       1137         520        558    214
# 1319  2021-04-28  0.001014        600       1104         504        452    184
# 1320  2021-04-29 -0.006826        462        805         343        455    153
# 1321  2021-04-30 -0.006860        894       1187         293        424    197
#
# [1322 rows x 7 columns]

# %%
MC_change = wsb_mktm.loc[:, ["change"]].values
MC_change
wsb_mmkt_X1 = wsb_mktm.loc[:,["Neg_Count", "Pos_Count", "favorites", "Count"]].values
wsb_mmkt_X1
# Out:
# array([[  30,   28,  224,    8],
#        [  27,   19,  156,    5],
#        [  62,   39,  664,   17],
#        ...,
#        [ 600, 1104,  452,  184],
#        [ 462,  805,  455,  153],
#        [ 894, 1187,  424,  197]], dtype=int64)

# %%
X_train, X_test,y_train,y_test = train_test_split(wsb_mmkt_X1, LC_change, test_size=0.33 , random_state=24)
regr = RandomForestRegressor()
regr.fit(X_train,y_train)
regr.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-219121081dca> in <module>
# ----> 1 X_train, X_test,y_train,y_test = train_test_split(wsb_mmkt_X1, LC_change, test_size=0.33 , random_state=24)
#       2 regr = RandomForestRegressor()
#       3 regr.fit(X_train,y_train)
#       4 regr.score(X_test, y_test)
#
# ~\Anaconda3\envs\pandas\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(*arrays, **options)
#    2094         raise TypeError("Invalid parameters passed: %s" % str(options))
#    2095
# -> 2096     arrays = indexable(*arrays)
#    2097
#    2098     n_samples = _num_samples(arrays[0])
#
# ~\Anaconda3\envs\pandas\lib\site-packages\sklearn\utils\validation.py in indexable(*iterables)
#     228         else:
#     229             result.append(np.array(X))
# --> 230     check_consistent_length(*result)
#     231     return result
#     232
#
# ~\Anaconda3\envs\pandas\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     203     if len(uniques) > 1:
#     204         raise ValueError("Found input variables with inconsistent numbers of"
# --> 205                          " samples: %r" % [int(l) for l in lengths])
#     206
#     207
#
# ValueError: Found input variables with inconsistent numbers of samples: [1322, 1307]

# %%
ridge.fit(X_train,y_train)
ridge.score(X_test, y_test)
# Out:
# 1.0

# %%
MC_change = wsb_mmkt.loc[:, ["change"]].values
MC_change
wsb_mmkt_X1 = wsb_mmkt.loc[:,["Sent_Count", "favorites", "Count"]].values
wsb_mmkt_X1

X_train, X_test,y_train,y_test = train_test_split(wsb_mmkt_X1, LC_change, test_size=0.33 , random_state=24)
regr = RandomForestRegressor()
regr.fit(X_train,y_train)
regr.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-af0ff7e3e29c> in <module>
#       4 wsb_mmkt_X1
#       5
# ----> 6 X_train, X_test,y_train,y_test = train_test_split(wsb_mmkt_X1, LC_change, test_size=0.33 , random_state=24)
#       7 regr = RandomForestRegressor()
#       8 regr.fit(X_train,y_train)
#
# ~\Anaconda3\envs\pandas\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(*arrays, **options)
#    2094         raise TypeError("Invalid parameters passed: %s" % str(options))
#    2095
# -> 2096     arrays = indexable(*arrays)
#    2097
#    2098     n_samples = _num_samples(arrays[0])
#
# ~\Anaconda3\envs\pandas\lib\site-packages\sklearn\utils\validation.py in indexable(*iterables)
#     228         else:
#     229             result.append(np.array(X))
# --> 230     check_consistent_length(*result)
#     231     return result
#     232
#
# ~\Anaconda3\envs\pandas\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     203     if len(uniques) > 1:
#     204         raise ValueError("Found input variables with inconsistent numbers of"
# --> 205                          " samples: %r" % [int(l) for l in lengths])
#     206
#     207
#
# ValueError: Found input variables with inconsistent numbers of samples: [1322, 1307]

# %%
ridge.fit(X_train,y_train)
ridge.score(X_test, y_test)

# %%
wsb_mkts = S_cap.merge(wsb_sentbydayneg, how='inner', left_on="date" ,right_on="Date")
wsb_mkts = wsb_mkts.merge(wsb_sentbydaypos, how='inner' ,on="Date")
wsb_mkts =  wsb_mkts.merge(wsb_sentbyday, how='inner' ,on="Date")
wsb_mkts =  wsb_mkts.merge(wsb_favd, how='inner' , left_on="date" ,right_on="day")
wsb_mkts =  wsb_mkts.merge(wsb_econ, how='inner' ,on="Date")
wsb_mkts

# %%
wsb_smkt = wsb_mkts.loc[:, ["date", "change", "Neg_Count", "Pos_Count", "Sent_Count", "favorites", "Count"]]
wsb_smkt

# %%
SC_change = wsb_mkts.loc[:, ["change"]].values
SC_change
wsb_smkt_X1 = wsb_mkts.loc[:,["Neg_Count", "Pos_Count", "favorites", "Count"]].values
wsb_smkt_X1

# %%
X_train, X_test,y_train,y_test = train_test_split(wsb_smkt_X1, LC_change, test_size=0.33 , random_state=24)
regr = RandomForestRegressor()
regr.fit(X_train,y_train)
regr.score(X_test, y_test)

# %%
ridge.fit(X_train,y_train)
ridge.score(X_test, y_test)

# %%
SC_change = wsb_mkts.loc[:, ["change"]].values
SC_change
wsb_smkt_X1 = wsb_mkts.loc[:,["Sent_Count", "favorites", "Count"]].values
wsb_smkt_X1

X_train, X_test,y_train,y_test = train_test_split(wsb_smkt_X1, LC_change, test_size=0.33 , random_state=24)
regr = RandomForestRegressor()
regr.fit(X_train,y_train)
regr.score(X_test, y_test)

# %%
ridge.fit(X_train,y_train)
ridge.score(X_test, y_test)
